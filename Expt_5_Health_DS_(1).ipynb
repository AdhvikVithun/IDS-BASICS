# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as py
import seaborn as sns

# %%
df=pd.read_csv("Health.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.read_csv("Health.csv")
#
# File c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\prath\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Health.csv'

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# 2                        0         7      Presence
# 3                        1         7       Absence
# 4                        1         3       Absence

# %%
df.tail()
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 265                        0         7       Absence
# 266                        0         7       Absence
# 267                        0         3       Absence
# 268                        0         6       Absence
# 269                        3         3      Presence

# %%
df.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# min        0.000000     0.000000   71.000000         0.000000        0.00000
# 25%        0.000000     0.000000  133.000000         0.000000        0.00000
# 50%        0.000000     2.000000  153.500000         0.000000        0.80000
# 75%        0.000000     2.000000  166.000000         1.000000        1.60000
# max        1.000000     2.000000  202.000000         1.000000        6.20000
#
#        Slope of ST  Number of vessels fluro    Thallium
# count   270.000000               270.000000  270.000000
# mean      1.585185                 0.670370    4.696296
# std       0.614390                 0.943896    1.940659
# min       1.000000                 0.000000    3.000000
# 25%       1.000000                 0.000000    3.000000
# 50%       2.000000                 0.000000    3.000000
# 75%       2.000000                 1.000000    7.000000
# max       3.000000                 3.000000    7.000000

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                          count        mean        std    min    25%    50%  \
# Age                      270.0   54.433333   9.109067   29.0   48.0   55.0
# Sex                      270.0    0.677778   0.468195    0.0    0.0    1.0
# Chest pain type          270.0    3.174074   0.950090    1.0    3.0    3.0
# BP                       270.0  131.344444  17.861608   94.0  120.0  130.0
# Cholesterol              270.0  249.659259  51.686237  126.0  213.0  245.0
# FBS over 120             270.0    0.148148   0.355906    0.0    0.0    0.0
# EKG results              270.0    1.022222   0.997891    0.0    0.0    2.0
# Max HR                   270.0  149.677778  23.165717   71.0  133.0  153.5
# Exercise angina          270.0    0.329630   0.470952    0.0    0.0    0.0
# ST depression            270.0    1.050000   1.145210    0.0    0.0    0.8
# Slope of ST              270.0    1.585185   0.614390    1.0    1.0    2.0
# Number of vessels fluro  270.0    0.670370   0.943896    0.0    0.0    0.0
# Thallium                 270.0    4.696296   1.940659    3.0    3.0    3.0
#
#                            75%    max
# Age                       61.0   77.0
# Sex                        1.0    1.0
# Chest pain type            4.0    4.0
# BP                       140.0  200.0
# Cholesterol              280.0  564.0
# FBS over 120               0.0    1.0
# EKG results                2.0    2.0
# Max HR                   166.0  202.0
# Exercise angina            1.0    1.0
# ST depression              1.6    6.2
# Slope of ST                2.0    3.0
# Number of vessels fluro    1.0    3.0
# Thallium                   7.0    7.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
#  13  Heart Disease            270 non-null    object
# dtypes: float64(1), int64(12), object(1)
# memory usage: 29.7+ KB

# %%
df.shape
# Out:
# (270, 14)

# %%
df.isna().any()
# Out:
# Age                        False
# Sex                        False
# Chest pain type            False
# BP                         False
# Cholesterol                False
# FBS over 120               False
# EKG results                False
# Max HR                     False
# Exercise angina            False
# ST depression              False
# Slope of ST                False
# Number of vessels fluro    False
# Thallium                   False
# Heart Disease              False
# dtype: bool

# %%
df['Age'].unique()
# Out:
# array([70, 67, 57, 64, 74, 65, 56, 59, 60, 63, 53, 44, 61, 71, 46, 40, 48,
#        43, 47, 54, 51, 58, 66, 37, 50, 42, 62, 49, 52, 45, 41, 76, 39, 35,
#        55, 34, 38, 69, 68, 77, 29])

# %%
df['Age'].value_counts()
# Out:
# 54    16
# 58    15
# 51    12
# 57    12
# 59    12
# 60    12
# 52    11
# 62    11
# 44    10
# 41     9
# 56     9
# 64     9
# 65     8
# 67     8
# 42     8
# 53     7
# 63     7
# 61     7
# 46     7
# 45     7
# 48     7
# 43     7
# 50     7
# 55     6
# 66     6
# 49     5
# 70     4
# 47     4
# 40     3
# 71     3
# 39     3
# 35     3
# 69     3
# 68     3
# 37     2
# 34     2
# 76     1
# 74     1
# 38     1
# 77     1
# 29     1
# Name: Age, dtype: int64

# %% [markdown]
# **5.1 Descriptive Statistics - Central Measures**

# %%
df['Age'].mean()
# Out:
# 54.43333333333333

# %%
df['Age'].median()
# Out:
# 55.0

# %%
import statistics as stat
stat.mode(df['Age'])
# Out:
# 54

# %% [markdown]
# **5.2 Descriptive Statistics - variable Measures**

# %%
df['Age'].std()
# Out:
# 9.109066523898207

# %%
df['Age'].var()
# Out:
# 82.97509293680295

# %%
df['Age'].quantile(0.25)
# Out:
# 48.0

# %%
df['Age'].quantile(0.75)
# Out:
# 61.0

# %% [markdown]
# **5.3 Descriptive Statistics - Correlation**

# %%
#Pearson Correlaion Coefficient
df.corr()
# Out:
# /var/folders/h4/4fpj068d71sgj9wbhdq3jxh80000gn/T/ipykernel_4094/3521174730.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.094401         0.096920  0.273053
# Sex                     -0.094401  1.000000         0.034636 -0.062693
# Chest pain type          0.096920  0.034636         1.000000 -0.043196
# BP                       0.273053 -0.062693        -0.043196  1.000000
# Cholesterol              0.220056 -0.201647         0.090465  0.173019
# FBS over 120             0.123458  0.042140        -0.098537  0.155681
# EKG results              0.128171  0.039253         0.074325  0.116157
# Max HR                  -0.402215 -0.076101        -0.317682 -0.039136
# Exercise angina          0.098297  0.180022         0.353160  0.082793
# ST depression            0.194234  0.097412         0.167244  0.222800
# Slope of ST              0.159774  0.050545         0.136900  0.142472
# Number of vessels fluro  0.356081  0.086830         0.225890  0.085697
# Thallium                 0.106100  0.391046         0.262659  0.132045
#
#                          Cholesterol  FBS over 120  EKG results    Max HR  \
# Age                         0.220056      0.123458     0.128171 -0.402215
# Sex                        -0.201647      0.042140     0.039253 -0.076101
# Chest pain type             0.090465     -0.098537     0.074325 -0.317682
# BP                          0.173019      0.155681     0.116157 -0.039136
# Cholesterol                 1.000000      0.025186     0.167652 -0.018739
# FBS over 120                0.025186      1.000000     0.053499  0.022494
# EKG results                 0.167652      0.053499     1.000000 -0.074628
# Max HR                     -0.018739      0.022494    -0.074628  1.000000
# Exercise angina             0.078243     -0.004107     0.095098 -0.380719
# ST depression               0.027709     -0.025538     0.120034 -0.349045
# Slope of ST                -0.005755      0.044076     0.160614 -0.386847
# Number of vessels fluro     0.126541      0.123774     0.114368 -0.265333
# Thallium                    0.028836      0.049237     0.007337 -0.253397
#
#                          Exercise angina  ST depression  Slope of ST  \
# Age                             0.098297       0.194234     0.159774
# Sex                             0.180022       0.097412     0.050545
# Chest pain type                 0.353160       0.167244     0.136900
# BP                              0.082793       0.222800     0.142472
# Cholesterol                     0.078243       0.027709    -0.005755
# FBS over 120                   -0.004107      -0.025538     0.044076
# EKG results                     0.095098       0.120034     0.160614
# Max HR                         -0.380719      -0.349045    -0.386847
# Exercise angina                 1.000000       0.274672     0.255908
# ST depression                   0.274672       1.000000     0.609712
# Slope of ST                     0.255908       0.609712     1.000000
# Number of vessels fluro         0.153347       0.255005     0.109498
# Thallium                        0.321449       0.324333     0.283678
#
#                          Number of vessels fluro  Thallium
# Age                                     0.356081  0.106100
# Sex                                     0.086830  0.391046
# Chest pain type                         0.225890  0.262659
# BP                                      0.085697  0.132045
# Cholesterol                             0.126541  0.028836
# FBS over 120                            0.123774  0.049237
# EKG results                             0.114368  0.007337
# Max HR                                 -0.265333 -0.253397
# Exercise angina                         0.153347  0.321449
# ST depression                           0.255005  0.324333
# Slope of ST                             0.109498  0.283678
# Number of vessels fluro                 1.000000  0.255648
# Thallium                                0.255648  1.000000

# %%
#Spearman Correlation
df.corr("spearman")
# Out:
# /var/folders/h4/4fpj068d71sgj9wbhdq3jxh80000gn/T/ipykernel_4094/2494919650.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr("spearman")
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.098542         0.120597  0.276844
# Sex                     -0.098542  1.000000         0.066653 -0.054963
# Chest pain type          0.120597  0.066653         1.000000 -0.001953
# BP                       0.276844 -0.054963        -0.001953  1.000000
# Cholesterol              0.211059 -0.158326         0.100225  0.190482
# FBS over 120             0.117920  0.042140        -0.107783  0.133742
# EKG results              0.128298  0.039491         0.110092  0.116558
# Max HR                  -0.399880 -0.076223        -0.349173 -0.042943
# Exercise angina          0.094830  0.180022         0.401879  0.070456
# ST depression            0.257712  0.111564         0.211559  0.182700
# Slope of ST              0.174111  0.051063         0.192331  0.107484
# Number of vessels fluro  0.374962  0.103746         0.250993  0.058231
# Thallium                 0.108891  0.382306         0.304878  0.107421
#
#                          Cholesterol  FBS over 120  EKG results    Max HR  \
# Age                         0.211059      0.117920     0.128298 -0.399880
# Sex                        -0.158326      0.042140     0.039491 -0.076223
# Chest pain type             0.100225     -0.107783     0.110092 -0.349173
# BP                          0.190482      0.133742     0.116558 -0.042943
# Cholesterol                 1.000000      0.032506     0.163601 -0.056473
# FBS over 120                0.032506      1.000000     0.053567  0.014583
# EKG results                 0.163601      0.053567     1.000000 -0.115033
# Max HR                     -0.056473      0.014583    -0.115033  1.000000
# Exercise angina             0.104276     -0.004107     0.095038 -0.394153
# ST depression               0.013844     -0.008769     0.110352 -0.423185
# Slope of ST                -0.000694      0.020992     0.161585 -0.427491
# Number of vessels fluro     0.154671      0.115877     0.110935 -0.290284
# Thallium                    0.019726      0.046360     0.005381 -0.269459
#
#                          Exercise angina  ST depression  Slope of ST  \
# Age                             0.094830       0.257712     0.174111
# Sex                             0.180022       0.111564     0.051063
# Chest pain type                 0.401879       0.211559     0.192331
# BP                              0.070456       0.182700     0.107484
# Cholesterol                     0.104276       0.013844    -0.000694
# FBS over 120                   -0.004107      -0.008769     0.020992
# EKG results                     0.095038       0.110352     0.161585
# Max HR                         -0.394153      -0.423185    -0.427491
# Exercise angina                 1.000000       0.276431     0.271273
# ST depression                   0.276431       1.000000     0.625263
# Slope of ST                     0.271273       0.625263     1.000000
# Number of vessels fluro         0.186474       0.241518     0.121699
# Thallium                        0.320636       0.339188     0.287708
#
#                          Number of vessels fluro  Thallium
# Age                                     0.374962  0.108891
# Sex                                     0.103746  0.382306
# Chest pain type                         0.250993  0.304878
# BP                                      0.058231  0.107421
# Cholesterol                             0.154671  0.019726
# FBS over 120                            0.115877  0.046360
# EKG results                             0.110935  0.005381
# Max HR                                 -0.290284 -0.269459
# Exercise angina                         0.186474  0.320636
# ST depression                           0.241518  0.339188
# Slope of ST                             0.121699  0.287708
# Number of vessels fluro                 1.000000  0.265755
# Thallium                                0.265755  1.000000

# %%
#Kendall Correlation
df.corr("kendall")
# Out:
# /var/folders/h4/4fpj068d71sgj9wbhdq3jxh80000gn/T/ipykernel_4094/52256917.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr("kendall")
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.081777         0.094603  0.195749
# Sex                     -0.081777  1.000000         0.062354 -0.046167
# Chest pain type          0.094603  0.062354         1.000000 -0.001118
# BP                       0.195749 -0.046167        -0.001118  1.000000
# Cholesterol              0.145815 -0.129861         0.075961  0.131595
# FBS over 120             0.097859  0.042140        -0.100831  0.112340
# EKG results              0.106030  0.039349         0.102903  0.097184
# Max HR                  -0.283426 -0.062743        -0.273658 -0.028597
# Exercise angina          0.078696  0.180022         0.375956  0.059181
# ST depression            0.184644  0.095535         0.170984  0.130070
# Slope of ST              0.140176  0.049722         0.175954  0.087898
# Number of vessels fluro  0.299595  0.097985         0.222620  0.046271
# Thallium                 0.087372  0.374139         0.277292  0.088398
#
#                          Cholesterol  FBS over 120  EKG results    Max HR  \
# Age                         0.145815      0.097859     0.106030 -0.283426
# Sex                        -0.129861      0.042140     0.039349 -0.062743
# Chest pain type             0.075961     -0.100831     0.102903 -0.273658
# BP                          0.131595      0.112340     0.097184 -0.028597
# Cholesterol                 1.000000      0.026662     0.133065 -0.037878
# FBS over 120                0.026662      1.000000     0.053374  0.012004
# EKG results                 0.133065      0.053374     1.000000 -0.093739
# Max HR                     -0.037878      0.012004    -0.093739  1.000000
# Exercise angina             0.085528     -0.004107     0.094696 -0.324446
# ST depression               0.012545     -0.007509     0.093842 -0.299864
# Slope of ST                -0.000847      0.020441     0.156984 -0.342886
# Number of vessels fluro     0.122784      0.109443     0.104315 -0.224881
# Thallium                    0.016097      0.045370     0.005282 -0.215913
#
#                          Exercise angina  ST depression  Slope of ST  \
# Age                             0.078696       0.184644     0.140176
# Sex                             0.180022       0.095535     0.049722
# Chest pain type                 0.375956       0.170984     0.175954
# BP                              0.059181       0.130070     0.087898
# Cholesterol                     0.085528       0.012545    -0.000847
# FBS over 120                   -0.004107      -0.007509     0.020441
# EKG results                     0.094696       0.093842     0.156984
# Max HR                         -0.324446      -0.299864    -0.342886
# Exercise angina                 1.000000       0.236715     0.264148
# ST depression                   0.236715       1.000000     0.532125
# Slope of ST                     0.264148       0.532125     1.000000
# Number of vessels fluro         0.176120       0.196251     0.112514
# Thallium                        0.313787       0.284711     0.274844
#
#                          Number of vessels fluro  Thallium
# Age                                     0.299595  0.087372
# Sex                                     0.097985  0.374139
# Chest pain type                         0.222620  0.277292
# BP                                      0.046271  0.088398
# Cholesterol                             0.122784  0.016097
# FBS over 120                            0.109443  0.045370
# EKG results                             0.104315  0.005282
# Max HR                                 -0.224881 -0.215913
# Exercise angina                         0.176120  0.313787
# ST depression                           0.196251  0.284711
# Slope of ST                             0.112514  0.274844
# Number of vessels fluro                 1.000000  0.246103
# Thallium                                0.246103  1.000000

# %% [markdown]
# **5.4 Descriptive Statistics - Visualization**

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Age'}>, <Axes: title={'center': 'Sex'}>,
#         <Axes: title={'center': 'Chest pain type'}>,
#         <Axes: title={'center': 'BP'}>],
#        [<Axes: title={'center': 'Cholesterol'}>,
#         <Axes: title={'center': 'FBS over 120'}>,
#         <Axes: title={'center': 'EKG results'}>,
#         <Axes: title={'center': 'Max HR'}>],
#        [<Axes: title={'center': 'Exercise angina'}>,
#         <Axes: title={'center': 'ST depression'}>,
#         <Axes: title={'center': 'Slope of ST'}>,
#         <Axes: title={'center': 'Number of vessels fluro'}>],
#        [<Axes: title={'center': 'Thallium'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
sns.boxplot(x="Sex", y="Age", data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x="Chest pain type", y="Age", data=df)
# Out:
# <Axes: xlabel='Chest pain type', ylabel='Age'>

# %%
#py.figure(figsize=(20,))
sns.pairplot(df)

# %%
pd.crosstab(df['Chest pain type'],df['Sex'] )
# Out:
# Sex               0   1
# Chest pain type
# 1                 4  16
# 2                16  26
# 3                32  47
# 4                35  94

# %%
sns.countplot(x="Chest pain type", hue="Sex", data=df)
# Out:
# <Axes: xlabel='Chest pain type', ylabel='count'>

# %%
sns.distplot(df['Age'])
# Out:
# /var/folders/h4/4fpj068d71sgj9wbhdq3jxh80000gn/T/ipykernel_4094/3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df.hist(by='Sex',column = 'Age')
# Out:
# array([<Axes: title={'center': '0'}>, <Axes: title={'center': '1'}>],
#       dtype=object)

# %%
py.figure(figsize=(20,5))
corr=df.corr()
sns.heatmap(corr, annot=True)
# Out:
# /var/folders/h4/4fpj068d71sgj9wbhdq3jxh80000gn/T/ipykernel_4094/645615144.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
# <Axes: >

# %% [markdown]
# # **Inferential Statistics**
#
# **5.5 Inferential Statistics - Point estimate**

# %%
df.shape
# Out:
# (270, 14)

# %%
df['Age'].mean()
# Out:
# 54.43333333333333

# %%
population = df['Age']
sample_ages = np.random.choice(a= population,size=50)            # Sample 500 values

print ( sample_ages.mean() )                         # Show sample mean

#Mean difference:
df['Age'].mean() - sample_ages.mean()   # Check difference between means
# Out:
# 54.16
# 0.27333333333333343

# %% [markdown]
# **5.6 Inferential Statistics - Sampling distribution of Mean**

# %% [markdown]
# From the difference we could understand the point estimate calculates with error value of 1.2. This shows that the population mean cannot by estimated by sampling mean.

# %%
point_estimates = []         # Make empty list to hold point estimates

for x in range(5):         # Generate 200 samples
    sample = np.random.choice(a= population, size=50)
    point_estimates.append( sample.mean() )
print(df['Age'].mean())
print(np.array(point_estimates).mean())
# Out:
# 54.43333333333333
# 54.788

# %% [markdown]
# **5.7 Inferential Statistics - Confidence Interval**

# %%
import math
import scipy.stats as stats
sample_size = 50
sample = np.random.choice(a= population, size = sample_size)
sample_mean = sample.mean()

z_critical = stats.norm.ppf(q = 0.975)  # Get the z-critical value*

print("z-critical value:")              # Check the z-critical value
print(z_critical)

pop_stdev = population.std()  # Get the population standard deviation

margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size))

confidence_interval = (sample_mean - margin_of_error,
                       sample_mean +


                       margin_of_error)

print("Confidence interval:")
print(confidence_interval)
# Out:
# z-critical value:
# 1.959963984540054
# Confidence interval:
# (54.05514197365477, 59.10485802634523)
